# %%
from lib import workflow_spam, workflow_diabetes

res_spam = workflow_spam("Data/spambase.data")
res_diab = workflow_diabetes("Data/diabetes_binary_health_indicators_BRFSS2015.csv")
res_spam, res_diab
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from lib import run_spam_workflow
#       3 results_spam = run_spam_workflow("Data/spambase.data")
#       4 results_spam
#
# ImportError: cannot import name 'run_spam_workflow' from 'lib' (unknown location)
